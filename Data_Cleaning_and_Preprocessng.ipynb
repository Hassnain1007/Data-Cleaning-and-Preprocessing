# %% [markdown]
# <a href="https://colab.research.google.com/github/Hassnain1007/Data-Cleaning-and-Preprocessing/blob/main/Data_Cleaning_and_Preprocessng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Loading the dataset
df = pd.read_csv("/netflix_titles.csv")

# Displaying the first 5 rows
print("Original Dataset:")
print(df.head())

# Checking if any missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Removing duplicate rows if any
df = df.drop_duplicates()

# Filling the missing values
df["director"] = df["director"].fillna("Unknown")
df["cast"] = df["cast"].fillna("Unknown")
df["country"] = df["country"].fillna("Unknown")
df["rating"] = df["rating"].fillna("Unknown")

for column in df.select_dtypes(include="object").columns:
    df[column] = df[column].str.strip()

df["date_added"] = pd.to_datetime(
    df["date_added"],
    errors="coerce"
)

df["year_added"] = df["date_added"].dt.year

df["duration_value"] = df["duration"].str.extract(r"(\d+)")

df.to_csv("netflix_cleaned.csv", index=False)

# Displaying final information
print("\nCleaning Completed!")
print("Final Dataset Shape:", df.shape)
print("\nCleaned Dataset:")
print(df.head())
